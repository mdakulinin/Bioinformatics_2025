# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.uniform(low=0, high=100, size=1000)

plt.figure(figsize=(8, 4))
plt.boxplot(data)
plt.title('Ящик с усами')
plt.xlabel('Значения')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
data = np.array([79, 80, 80, 80, 74, 80, 80, 79, 64, 78, 73, 78, 74, 45, 81, 48, 80, 82, 82, 70])

q1 = np.percentile(data, 25)
median = np.percentile(data, 50)
q3 = np.percentile(data, 75)

iqr = q3 - q1

lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = data[(data < lower_bound) | (data > upper_bound)]

plt.figure(figsize=(8, 4))
plt.boxplot(data)
plt.title('Ящик с усами')
plt.xlabel('Значения')
plt.grid(True)
plt.tight_layout()
plt.show()

(q1, median, q3, iqr, data.min(), data.max(), outliers)
# Out:
# (73.75, 79.0, 80.0, 6.25, 45, 82, array([64, 45, 48]))
