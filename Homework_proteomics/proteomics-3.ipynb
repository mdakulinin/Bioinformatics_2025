# %%
from os import listdir, path
from pyteomics import fasta
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.stats.multitest import multipletests
from scipy import stats
import numpy as np
from glob import glob
import os
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.formula.api import ols
sns.set_style('whitegrid')

# %%
fastafile = '/projects/mipt_dbmp_biotechnology/proteomics/sp_human_canonical_2023-09-06_shuffled.fasta'

# %% [markdown]
# Задача: сравни

# %% [markdown]
# # Конвертация сырых спектров в mzML (26 минут, предлагаю показать на одном файле)

# %%
# !for file in /projects/mipt_dbmp_biotechnology/proteomics/hw; do /projects/mipt_dbmp_biotechnology/soft/ThermoRawFileParser/ThermoRawFileParser -i $file -o $mzML; done

# %% [markdown]
# # Идентификация белков (на 32 Гб и 40 потоках 6 минут)

# %% [markdown]
# Запускаем MSFragger через slurm

# %% [markdown]
# # Пост-поисковая валидация (15 минут)

# %%
# %%time
filedir = 'mzML'
outdir = 'mzML'
for file in listdir(filedir):
    filename = file.split('.')[0] 
    if file.endswith('.pepXML') and filename + '_protein_groups.tsv' not in listdir(outdir):
        print(file)
        path_to_pepxml = path.join(filedir, file)
        # !scavager -p DECOY_ -db $fastafile -o $outdir $path_to_pepxml
# Out:
# LUM2_00721_VG_3821B_1.pepXML
#      INFO: [06:16:09] 1 file(s) to process.
#      INFO: [06:16:10] Loading file LUM2_00721_VG_3821B_1.pepXML...
#      INFO: [06:16:21] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 39344
#      INFO: [06:16:21] Calibrating retention model...
#      INFO: [06:16:42] RT model training results: R^2 = 0.848568 , std = 10.958476
#      INFO: [06:16:42] Retention model calibrated successfully.
#      INFO: [06:16:43] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:17:03] Machine learning is finished.
#      INFO: [06:17:08] Final results at 1.0% FDR level:
#      INFO: [06:17:08] Identified PSMs: 40328
#      INFO: [06:17:08] Identified peptides: 28647
#      INFO: [06:17:08] Identified proteins: 4864
#      INFO: [06:17:08] Identified protein groups: 4260
#      INFO: [06:17:08] Processing finished.
#      INFO: [06:17:11] Output tables saved.
#      INFO: [06:17:20] Figures saved.
# LUM2_00840_VG_4114K_6.pepXML
#      INFO: [06:17:22] 1 file(s) to process.
#      INFO: [06:17:22] Loading file LUM2_00840_VG_4114K_6.pepXML...
#      INFO: [06:17:31] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 29492
#      INFO: [06:17:31] Calibrating retention model...
#      INFO: [06:17:46] RT model training results: R^2 = 0.856200 , std = 10.714500
#      INFO: [06:17:46] Retention model calibrated successfully.
#      INFO: [06:17:47] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:18:06] Machine learning is finished.
#      INFO: [06:18:10] Final results at 1.0% FDR level:
#      INFO: [06:18:10] Identified PSMs: 30942
#      INFO: [06:18:10] Identified peptides: 22379
#      INFO: [06:18:10] Identified proteins: 4015
#      INFO: [06:18:10] Identified protein groups: 3516
#      INFO: [06:18:10] Processing finished.
#      INFO: [06:18:12] Output tables saved.
#      INFO: [06:18:20] Figures saved.
# LUM2_00818_VG_4114B_2.pepXML
#      INFO: [06:18:22] 1 file(s) to process.
#      INFO: [06:18:22] Loading file LUM2_00818_VG_4114B_2.pepXML...
#      INFO: [06:18:29] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 26867
#      INFO: [06:18:29] Calibrating retention model...
#      INFO: [06:18:44] RT model training results: R^2 = 0.850104 , std = 10.984422
#      INFO: [06:18:44] Retention model calibrated successfully.
#      INFO: [06:18:44] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:19:07] Machine learning is finished.
#      INFO: [06:19:10] Final results at 1.0% FDR level:
#      INFO: [06:19:10] Identified PSMs: 28235
#      INFO: [06:19:10] Identified peptides: 21461
#      INFO: [06:19:10] Identified proteins: 3983
#      INFO: [06:19:10] Identified protein groups: 3471
#      INFO: [06:19:10] Processing finished.
#      INFO: [06:19:13] Output tables saved.
#      INFO: [06:19:20] Figures saved.
# LUM2_00712_VG_3821K_4.pepXML
#      INFO: [06:19:22] 1 file(s) to process.
#      INFO: [06:19:22] Loading file LUM2_00712_VG_3821K_4.pepXML...
#      INFO: [06:19:34] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 33791
#      INFO: [06:19:34] Calibrating retention model...
#      INFO: [06:19:52] RT model training results: R^2 = 0.867703 , std = 9.926906
#      INFO: [06:19:52] Retention model calibrated successfully.
#      INFO: [06:19:52] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:20:11] Machine learning is finished.
#      INFO: [06:20:16] Final results at 1.0% FDR level:
#      INFO: [06:20:16] Identified PSMs: 35321
#      INFO: [06:20:16] Identified peptides: 25549
#      INFO: [06:20:16] Identified proteins: 4528
#      INFO: [06:20:16] Identified protein groups: 3971
#      INFO: [06:20:16] Processing finished.
#      INFO: [06:20:19] Output tables saved.
#      INFO: [06:20:27] Figures saved.
# LUM2_00741_VG_3821A_2.pepXML
#      INFO: [06:20:29] 1 file(s) to process.
#      INFO: [06:20:29] Loading file LUM2_00741_VG_3821A_2.pepXML...
#      INFO: [06:20:40] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 37690
#      INFO: [06:20:40] Calibrating retention model...
#      INFO: [06:21:00] RT model training results: R^2 = 0.871145 , std = 10.135037
#      INFO: [06:21:00] Retention model calibrated successfully.
#      INFO: [06:21:00] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:21:19] Machine learning is finished.
#      INFO: [06:21:24] Final results at 1.0% FDR level:
#      INFO: [06:21:24] Identified PSMs: 38613
#      INFO: [06:21:24] Identified peptides: 27476
#      INFO: [06:21:24] Identified proteins: 4828
#      INFO: [06:21:24] Identified protein groups: 4240
#      INFO: [06:21:24] Processing finished.
#      INFO: [06:21:27] Output tables saved.
#      INFO: [06:21:35] Figures saved.
# LUM2_00711_VG_3821K_3.pepXML
#      INFO: [06:21:37] 1 file(s) to process.
#      INFO: [06:21:37] Loading file LUM2_00711_VG_3821K_3.pepXML...
#      INFO: [06:21:49] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 34048
#      INFO: [06:21:49] Calibrating retention model...
#      INFO: [06:22:07] RT model training results: R^2 = 0.872888 , std = 9.779537
#      INFO: [06:22:07] Retention model calibrated successfully.
#      INFO: [06:22:07] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:22:29] Machine learning is finished.
#      INFO: [06:22:34] Final results at 1.0% FDR level:
#      INFO: [06:22:34] Identified PSMs: 35533
#      INFO: [06:22:34] Identified peptides: 25810
#      INFO: [06:22:34] Identified proteins: 4545
#      INFO: [06:22:34] Identified protein groups: 3977
#      INFO: [06:22:34] Processing finished.
#      INFO: [06:22:37] Output tables saved.
#      INFO: [06:22:45] Figures saved.
# LUM2_00806_VG_6138A_1.pepXML
#      INFO: [06:22:47] 1 file(s) to process.
#      INFO: [06:22:47] Loading file LUM2_00806_VG_6138A_1.pepXML...
#      INFO: [06:22:57] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 27768
#      INFO: [06:22:57] Calibrating retention model...
#      INFO: [06:23:14] RT model training results: R^2 = 0.857580 , std = 11.108044
#      INFO: [06:23:14] Retention model calibrated successfully.
#      INFO: [06:23:14] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:23:33] Machine learning is finished.
#      INFO: [06:23:37] Final results at 1.0% FDR level:
#      INFO: [06:23:37] Identified PSMs: 29284
#      INFO: [06:23:37] Identified peptides: 21582
#      INFO: [06:23:37] Identified proteins: 4098
#      INFO: [06:23:37] Identified protein groups: 3626
#      INFO: [06:23:37] Processing finished.
#      INFO: [06:23:39] Output tables saved.
#      INFO: [06:23:47] Figures saved.
# LUM2_00742_VG_3821A_3.pepXML
#      INFO: [06:23:49] 1 file(s) to process.
#      INFO: [06:23:49] Loading file LUM2_00742_VG_3821A_3.pepXML...
#      INFO: [06:24:00] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 37673
#      INFO: [06:24:00] Calibrating retention model...
#      INFO: [06:24:21] RT model training results: R^2 = 0.873091 , std = 10.060128
#      INFO: [06:24:21] Retention model calibrated successfully.
#      INFO: [06:24:21] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:24:42] Machine learning is finished.
#      INFO: [06:24:47] Final results at 1.0% FDR level:
#      INFO: [06:24:47] Identified PSMs: 38530
#      INFO: [06:24:47] Identified peptides: 27571
#      INFO: [06:24:47] Identified proteins: 4776
#      INFO: [06:24:47] Identified protein groups: 4154
#      INFO: [06:24:47] Processing finished.
#      INFO: [06:24:49] Output tables saved.
#      INFO: [06:24:58] Figures saved.
# LUM2_00856_VG_4114A_4.pepXML
#      INFO: [06:25:00] 1 file(s) to process.
#      INFO: [06:25:00] Loading file LUM2_00856_VG_4114A_4.pepXML...
#      INFO: [06:25:10] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 30284
#      INFO: [06:25:10] Calibrating retention model...
#      INFO: [06:25:27] RT model training results: R^2 = 0.845865 , std = 11.370973
#      INFO: [06:25:27] Retention model calibrated successfully.
#      INFO: [06:25:27] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:25:48] Machine learning is finished.
#      INFO: [06:25:52] Final results at 1.0% FDR level:
#      INFO: [06:25:52] Identified PSMs: 31477
#      INFO: [06:25:52] Identified peptides: 23139
#      INFO: [06:25:52] Identified proteins: 4245
#      INFO: [06:25:52] Identified protein groups: 3743
#      INFO: [06:25:52] Processing finished.
#      INFO: [06:25:55] Output tables saved.
#      INFO: [06:26:03] Figures saved.
# LUM2_00743_VG_3821A_4.pepXML
#      INFO: [06:26:05] 1 file(s) to process.
#      INFO: [06:26:05] Loading file LUM2_00743_VG_3821A_4.pepXML...
#      INFO: [06:26:16] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 37720
#      INFO: [06:26:16] Calibrating retention model...
#      INFO: [06:26:36] RT model training results: R^2 = 0.874916 , std = 9.977834
#      INFO: [06:26:36] Retention model calibrated successfully.
#      INFO: [06:26:37] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:26:57] Machine learning is finished.
#      INFO: [06:27:02] Final results at 1.0% FDR level:
#      INFO: [06:27:02] Identified PSMs: 38808
#      INFO: [06:27:02] Identified peptides: 27653
#      INFO: [06:27:02] Identified proteins: 4841
#      INFO: [06:27:02] Identified protein groups: 4202
#      INFO: [06:27:02] Processing finished.
#      INFO: [06:27:05] Output tables saved.
#      INFO: [06:27:13] Figures saved.
# LUM2_00839_VG_4114K_5.pepXML
#      INFO: [06:27:15] 1 file(s) to process.
#      INFO: [06:27:15] Loading file LUM2_00839_VG_4114K_5.pepXML...
#      INFO: [06:27:25] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 29944
#      INFO: [06:27:25] Calibrating retention model...
#      INFO: [06:27:41] RT model training results: R^2 = 0.855992 , std = 10.737188
#      INFO: [06:27:41] Retention model calibrated successfully.
#      INFO: [06:27:42] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:28:01] Machine learning is finished.
#      INFO: [06:28:05] Final results at 1.0% FDR level:
#      INFO: [06:28:05] Identified PSMs: 31391
#      INFO: [06:28:05] Identified peptides: 22811
#      INFO: [06:28:05] Identified proteins: 3987
#      INFO: [06:28:05] Identified protein groups: 3502
#      INFO: [06:28:05] Processing finished.
#      INFO: [06:28:07] Output tables saved.
#      INFO: [06:28:15] Figures saved.
# LUM2_00841_VG_4114K_7.pepXML
#      INFO: [06:28:17] 1 file(s) to process.
#      INFO: [06:28:17] Loading file LUM2_00841_VG_4114K_7.pepXML...
#      INFO: [06:28:26] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 29411
#      INFO: [06:28:26] Calibrating retention model...
#      INFO: [06:28:43] RT model training results: R^2 = 0.847422 , std = 10.973701
#      INFO: [06:28:43] Retention model calibrated successfully.
#      INFO: [06:28:43] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:29:01] Machine learning is finished.
#      INFO: [06:29:05] Final results at 1.0% FDR level:
#      INFO: [06:29:05] Identified PSMs: 30597
#      INFO: [06:29:05] Identified peptides: 22148
#      INFO: [06:29:05] Identified proteins: 4092
#      INFO: [06:29:05] Identified protein groups: 3592
#      INFO: [06:29:05] Processing finished.
#      INFO: [06:29:08] Output tables saved.
#      INFO: [06:29:16] Figures saved.
# LUM2_00820_VG_4114B_4.pepXML
#      INFO: [06:29:18] 1 file(s) to process.
#      INFO: [06:29:18] Loading file LUM2_00820_VG_4114B_4.pepXML...
#      INFO: [06:29:26] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 27018
#      INFO: [06:29:26] Calibrating retention model...
#      INFO: [06:29:41] RT model training results: R^2 = 0.849215 , std = 11.023934
#      INFO: [06:29:41] Retention model calibrated successfully.
#      INFO: [06:29:41] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:30:00] Machine learning is finished.
#      INFO: [06:30:04] Final results at 1.0% FDR level:
#      INFO: [06:30:04] Identified PSMs: 28506
#      INFO: [06:30:04] Identified peptides: 21597
#      INFO: [06:30:04] Identified proteins: 3963
#      INFO: [06:30:04] Identified protein groups: 3450
#      INFO: [06:30:04] Processing finished.
#      INFO: [06:30:06] Output tables saved.
#      INFO: [06:30:14] Figures saved.
# LUM2_00801_VG_6138B_4.pepXML
#      INFO: [06:30:16] 1 file(s) to process.
#      INFO: [06:30:16] Loading file LUM2_00801_VG_6138B_4.pepXML...
#      INFO: [06:30:26] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 31291
#      INFO: [06:30:26] Calibrating retention model...
#      INFO: [06:30:43] RT model training results: R^2 = 0.856623 , std = 10.957499
#      INFO: [06:30:43] Retention model calibrated successfully.
#      INFO: [06:30:44] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:31:06] Machine learning is finished.
#      INFO: [06:31:10] Final results at 1.0% FDR level:
#      INFO: [06:31:10] Identified PSMs: 32616
#      INFO: [06:31:10] Identified peptides: 23310
#      INFO: [06:31:10] Identified proteins: 4094
#      INFO: [06:31:10] Identified protein groups: 3666
#      INFO: [06:31:10] Processing finished.
#      INFO: [06:31:13] Output tables saved.
#      INFO: [06:31:21] Figures saved.
# LUM2_00724_VG_3821B_4.pepXML
#      INFO: [06:31:23] 1 file(s) to process.
#      INFO: [06:31:23] Loading file LUM2_00724_VG_3821B_4.pepXML...
#      INFO: [06:31:35] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 37249
#      INFO: [06:31:35] Calibrating retention model...
#      INFO: [06:31:55] RT model training results: R^2 = 0.856524 , std = 10.457933
#      INFO: [06:31:55] Retention model calibrated successfully.
#      INFO: [06:31:56] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:32:17] Machine learning is finished.
#      INFO: [06:32:22] Final results at 1.0% FDR level:
#      INFO: [06:32:22] Identified PSMs: 38601
#      INFO: [06:32:22] Identified peptides: 27995
#      INFO: [06:32:22] Identified proteins: 4837
#      INFO: [06:32:22] Identified protein groups: 4193
#      INFO: [06:32:22] Processing finished.
#      INFO: [06:32:25] Output tables saved.
#      INFO: [06:32:34] Figures saved.
# LUM2_00710_VG_3821K_2.pepXML
#      INFO: [06:32:36] 1 file(s) to process.
#      INFO: [06:32:36] Loading file LUM2_00710_VG_3821K_2.pepXML...
#      INFO: [06:32:47] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 35631
#      INFO: [06:32:47] Calibrating retention model...
#      INFO: [06:33:06] RT model training results: R^2 = 0.865967 , std = 10.171927
#      INFO: [06:33:06] Retention model calibrated successfully.
#      INFO: [06:33:07] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:33:29] Machine learning is finished.
#      INFO: [06:33:34] Final results at 1.0% FDR level:
#      INFO: [06:33:34] Identified PSMs: 36782
#      INFO: [06:33:34] Identified peptides: 26206
#      INFO: [06:33:34] Identified proteins: 4718
#      INFO: [06:33:34] Identified protein groups: 3994
#      INFO: [06:33:34] Processing finished.
#      INFO: [06:33:37] Output tables saved.
#      INFO: [06:33:45] Figures saved.
# LUM2_00855_VG_4114A_3.pepXML
#      INFO: [06:33:47] 1 file(s) to process.
#      INFO: [06:33:47] Loading file LUM2_00855_VG_4114A_3.pepXML...
#      INFO: [06:33:57] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 30270
#      INFO: [06:33:57] Calibrating retention model...
#      INFO: [06:34:15] RT model training results: R^2 = 0.846277 , std = 11.241714
#      INFO: [06:34:15] Retention model calibrated successfully.
#      INFO: [06:34:15] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:34:35] Machine learning is finished.
#      INFO: [06:34:39] Final results at 1.0% FDR level:
#      INFO: [06:34:39] Identified PSMs: 31665
#      INFO: [06:34:39] Identified peptides: 23210
#      INFO: [06:34:39] Identified proteins: 4247
#      INFO: [06:34:39] Identified protein groups: 3751
#      INFO: [06:34:39] Processing finished.
#      INFO: [06:34:41] Output tables saved.
#      INFO: [06:34:50] Figures saved.
# LUM2_00853_VG_4114A_1.pepXML
#      INFO: [06:34:51] 1 file(s) to process.
#      INFO: [06:34:52] Loading file LUM2_00853_VG_4114A_1.pepXML...
#      INFO: [06:35:02] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 30798
#      INFO: [06:35:02] Calibrating retention model...
#      INFO: [06:35:19] RT model training results: R^2 = 0.853982 , std = 10.983484
#      INFO: [06:35:19] Retention model calibrated successfully.
#      INFO: [06:35:19] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:35:40] Machine learning is finished.
#      INFO: [06:35:44] Final results at 1.0% FDR level:
#      INFO: [06:35:44] Identified PSMs: 32075
#      INFO: [06:35:44] Identified peptides: 23371
#      INFO: [06:35:44] Identified proteins: 4291
#      INFO: [06:35:44] Identified protein groups: 3761
#      INFO: [06:35:44] Processing finished.
#      INFO: [06:35:47] Output tables saved.
#      INFO: [06:35:55] Figures saved.
# LUM2_00837_VG_4114K_3.pepXML
#      INFO: [06:35:57] 1 file(s) to process.
#      INFO: [06:35:57] Loading file LUM2_00837_VG_4114K_3.pepXML...
#      INFO: [06:36:07] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 29616
#      INFO: [06:36:07] Calibrating retention model...
#      INFO: [06:36:23] RT model training results: R^2 = 0.854583 , std = 10.792878
#      INFO: [06:36:23] Retention model calibrated successfully.
#      INFO: [06:36:23] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:36:41] Machine learning is finished.
#      INFO: [06:36:45] Final results at 1.0% FDR level:
#      INFO: [06:36:45] Identified PSMs: 30913
#      INFO: [06:36:45] Identified peptides: 22621
#      INFO: [06:36:45] Identified proteins: 4034
#      INFO: [06:36:45] Identified protein groups: 3542
#      INFO: [06:36:45] Processing finished.
#      INFO: [06:36:48] Output tables saved.
#      INFO: [06:36:55] Figures saved.
# LUM2_00838_VG_4114K_4.pepXML
#      INFO: [06:36:57] 1 file(s) to process.
#      INFO: [06:36:57] Loading file LUM2_00838_VG_4114K_4.pepXML...
#      INFO: [06:37:07] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 29571
#      INFO: [06:37:07] Calibrating retention model...
#      INFO: [06:37:23] RT model training results: R^2 = 0.851101 , std = 10.885744
#      INFO: [06:37:23] Retention model calibrated successfully.
#      INFO: [06:37:24] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:37:43] Machine learning is finished.
#      INFO: [06:37:47] Final results at 1.0% FDR level:
#      INFO: [06:37:47] Identified PSMs: 30928
#      INFO: [06:37:47] Identified peptides: 22356
#      INFO: [06:37:47] Identified proteins: 3966
#      INFO: [06:37:47] Identified protein groups: 3496
#      INFO: [06:37:47] Processing finished.
#      INFO: [06:37:50] Output tables saved.
#      INFO: [06:37:58] Figures saved.
# LUM2_00799_VG_6138B_2.pepXML
#      INFO: [06:38:00] 1 file(s) to process.
#      INFO: [06:38:00] Loading file LUM2_00799_VG_6138B_2.pepXML...
#      INFO: [06:38:10] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 31951
#      INFO: [06:38:10] Calibrating retention model...
#      INFO: [06:38:28] RT model training results: R^2 = 0.856950 , std = 11.025009
#      INFO: [06:38:28] Retention model calibrated successfully.
#      INFO: [06:38:28] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:38:50] Machine learning is finished.
#      INFO: [06:38:54] Final results at 1.0% FDR level:
#      INFO: [06:38:54] Identified PSMs: 33102
#      INFO: [06:38:54] Identified peptides: 23621
#      INFO: [06:38:54] Identified proteins: 4234
#      INFO: [06:38:54] Identified protein groups: 3787
#      INFO: [06:38:54] Processing finished.
#      INFO: [06:38:57] Output tables saved.
#      INFO: [06:39:05] Figures saved.
# LUM2_00822_VG_4114B_6.pepXML
#      INFO: [06:39:07] 1 file(s) to process.
#      INFO: [06:39:08] Loading file LUM2_00822_VG_4114B_6.pepXML...
#      INFO: [06:39:15] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 27716
#      INFO: [06:39:15] Calibrating retention model...
#      INFO: [06:39:30] RT model training results: R^2 = 0.842082 , std = 11.362440
#      INFO: [06:39:30] Retention model calibrated successfully.
#      INFO: [06:39:31] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:39:51] Machine learning is finished.
#      INFO: [06:39:55] Final results at 1.0% FDR level:
#      INFO: [06:39:55] Identified PSMs: 28856
#      INFO: [06:39:55] Identified peptides: 21680
#      INFO: [06:39:55] Identified proteins: 3992
#      INFO: [06:39:55] Identified protein groups: 3483
#      INFO: [06:39:55] Processing finished.
#      INFO: [06:39:57] Output tables saved.
#      INFO: [06:40:04] Figures saved.
# LUM2_00823_VG_4114B_7.pepXML
#      INFO: [06:40:06] 1 file(s) to process.
#      INFO: [06:40:06] Loading file LUM2_00823_VG_4114B_7.pepXML...
#      INFO: [06:40:14] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 27541
#      INFO: [06:40:14] Calibrating retention model...
#      INFO: [06:40:29] RT model training results: R^2 = 0.848823 , std = 10.958646
#      INFO: [06:40:29] Retention model calibrated successfully.
#      INFO: [06:40:29] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:40:51] Machine learning is finished.
#      INFO: [06:40:54] Final results at 1.0% FDR level:
#      INFO: [06:40:54] Identified PSMs: 28924
#      INFO: [06:40:54] Identified peptides: 21516
#      INFO: [06:40:54] Identified proteins: 4104
#      INFO: [06:40:54] Identified protein groups: 3596
#      INFO: [06:40:54] Processing finished.
#      INFO: [06:40:57] Output tables saved.
#      INFO: [06:41:04] Figures saved.
# LUM2_00740_VG_3821A_1.pepXML
#      INFO: [06:41:06] 1 file(s) to process.
#      INFO: [06:41:07] Loading file LUM2_00740_VG_3821A_1.pepXML...
#      INFO: [06:41:17] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 38058
#      INFO: [06:41:17] Calibrating retention model...
#      INFO: [06:41:38] RT model training results: R^2 = 0.879010 , std = 9.787894
#      INFO: [06:41:38] Retention model calibrated successfully.
#      INFO: [06:41:38] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:41:59] Machine learning is finished.
#      INFO: [06:42:04] Final results at 1.0% FDR level:
#      INFO: [06:42:04] Identified PSMs: 39171
#      INFO: [06:42:04] Identified peptides: 27992
#      INFO: [06:42:04] Identified proteins: 4724
#      INFO: [06:42:04] Identified protein groups: 4179
#      INFO: [06:42:04] Processing finished.
#      INFO: [06:42:07] Output tables saved.
#      INFO: [06:42:15] Figures saved.
# LUM2_00836_VG_4114K_2.pepXML
#      INFO: [06:42:17] 1 file(s) to process.
#      INFO: [06:42:17] Loading file LUM2_00836_VG_4114K_2.pepXML...
#      INFO: [06:42:26] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 29951
#      INFO: [06:42:26] Calibrating retention model...
#      INFO: [06:42:42] RT model training results: R^2 = 0.847398 , std = 11.111749
#      INFO: [06:42:42] Retention model calibrated successfully.
#      INFO: [06:42:42] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:43:02] Machine learning is finished.
#      INFO: [06:43:06] Final results at 1.0% FDR level:
#      INFO: [06:43:06] Identified PSMs: 31090
#      INFO: [06:43:06] Identified peptides: 22557
#      INFO: [06:43:06] Identified proteins: 4051
#      INFO: [06:43:06] Identified protein groups: 3561
#      INFO: [06:43:06] Processing finished.
#      INFO: [06:43:08] Output tables saved.
#      INFO: [06:43:16] Figures saved.
# LUM2_00793_VG_6138K_4.pepXML
#      INFO: [06:43:18] 1 file(s) to process.
#      INFO: [06:43:18] Loading file LUM2_00793_VG_6138K_4.pepXML...
#      INFO: [06:43:30] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 30358
#      INFO: [06:43:30] Calibrating retention model...
#      INFO: [06:43:47] RT model training results: R^2 = 0.848696 , std = 11.230555
#      INFO: [06:43:47] Retention model calibrated successfully.
#      INFO: [06:43:47] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:44:09] Machine learning is finished.
#      INFO: [06:44:14] Final results at 1.0% FDR level:
#      INFO: [06:44:14] Identified PSMs: 31659
#      INFO: [06:44:14] Identified peptides: 22621
#      INFO: [06:44:14] Identified proteins: 4480
#      INFO: [06:44:14] Identified protein groups: 3942
#      INFO: [06:44:14] Processing finished.
#      INFO: [06:44:17] Output tables saved.
#      INFO: [06:44:25] Figures saved.
# LUM2_00857_VG_4114A_5.pepXML
#      INFO: [06:44:27] 1 file(s) to process.
#      INFO: [06:44:27] Loading file LUM2_00857_VG_4114A_5.pepXML...
#      INFO: [06:44:36] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 30616
#      INFO: [06:44:36] Calibrating retention model...
#      INFO: [06:44:53] RT model training results: R^2 = 0.842513 , std = 11.500050
#      INFO: [06:44:53] Retention model calibrated successfully.
#      INFO: [06:44:53] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:45:11] Machine learning is finished.
#      INFO: [06:45:16] Final results at 1.0% FDR level:
#      INFO: [06:45:16] Identified PSMs: 31717
#      INFO: [06:45:16] Identified peptides: 23404
#      INFO: [06:45:16] Identified proteins: 4346
#      INFO: [06:45:16] Identified protein groups: 3807
#      INFO: [06:45:16] Processing finished.
#      INFO: [06:45:18] Output tables saved.
#      INFO: [06:45:26] Figures saved.
# LUM2_00821_VG_4114B_5.pepXML
#      INFO: [06:45:28] 1 file(s) to process.
#      INFO: [06:45:28] Loading file LUM2_00821_VG_4114B_5.pepXML...
#      INFO: [06:45:36] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 27603
#      INFO: [06:45:36] Calibrating retention model...
#      INFO: [06:45:51] RT model training results: R^2 = 0.844927 , std = 11.258953
#      INFO: [06:45:51] Retention model calibrated successfully.
#      INFO: [06:45:51] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:46:12] Machine learning is finished.
#      INFO: [06:46:15] Final results at 1.0% FDR level:
#      INFO: [06:46:15] Identified PSMs: 28621
#      INFO: [06:46:15] Identified peptides: 21607
#      INFO: [06:46:15] Identified proteins: 3985
#      INFO: [06:46:15] Identified protein groups: 3464
#      INFO: [06:46:15] Processing finished.
#      INFO: [06:46:17] Output tables saved.
#      INFO: [06:46:25] Figures saved.
# LUM2_00790_VG_6138K_1.pepXML
#      INFO: [06:46:27] 1 file(s) to process.
#      INFO: [06:46:27] Loading file LUM2_00790_VG_6138K_1.pepXML...
#      INFO: [06:46:39] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 30332
#      INFO: [06:46:39] Calibrating retention model...
#      INFO: [06:46:55] RT model training results: R^2 = 0.862138 , std = 10.800125
#      INFO: [06:46:55] Retention model calibrated successfully.
#      INFO: [06:46:56] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:47:17] Machine learning is finished.
#      INFO: [06:47:22] Final results at 1.0% FDR level:
#      INFO: [06:47:22] Identified PSMs: 31807
#      INFO: [06:47:22] Identified peptides: 23212
#      INFO: [06:47:22] Identified proteins: 4358
#      INFO: [06:47:22] Identified protein groups: 3857
#      INFO: [06:47:22] Processing finished.
#      INFO: [06:47:25] Output tables saved.
#      INFO: [06:47:33] Figures saved.
# LUM2_00807_VG_6138A_2.pepXML
#      INFO: [06:47:35] 1 file(s) to process.
#      INFO: [06:47:35] Loading file LUM2_00807_VG_6138A_2.pepXML...
#      INFO: [06:47:44] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 26890
#      INFO: [06:47:44] Calibrating retention model...
#      INFO: [06:48:00] RT model training results: R^2 = 0.862397 , std = 10.874756
#      INFO: [06:48:00] Retention model calibrated successfully.
#      INFO: [06:48:00] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:48:23] Machine learning is finished.
#      INFO: [06:48:27] Final results at 1.0% FDR level:
#      INFO: [06:48:27] Identified PSMs: 28505
#      INFO: [06:48:27] Identified peptides: 20949
#      INFO: [06:48:27] Identified proteins: 3982
#      INFO: [06:48:27] Identified protein groups: 3535
#      INFO: [06:48:27] Processing finished.
#      INFO: [06:48:30] Output tables saved.
#      INFO: [06:48:37] Figures saved.
# LUM2_00791_VG_6138K_2.pepXML
#      INFO: [06:48:39] 1 file(s) to process.
#      INFO: [06:48:40] Loading file LUM2_00791_VG_6138K_2.pepXML...
#      INFO: [06:48:51] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 30218
#      INFO: [06:48:51] Calibrating retention model...
#      INFO: [06:49:08] RT model training results: R^2 = 0.861312 , std = 10.836913
#      INFO: [06:49:08] Retention model calibrated successfully.
#      INFO: [06:49:09] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:49:31] Machine learning is finished.
#      INFO: [06:49:36] Final results at 1.0% FDR level:
#      INFO: [06:49:36] Identified PSMs: 31838
#      INFO: [06:49:36] Identified peptides: 23049
#      INFO: [06:49:36] Identified proteins: 4520
#      INFO: [06:49:36] Identified protein groups: 3967
#      INFO: [06:49:36] Processing finished.
#      INFO: [06:49:39] Output tables saved.
#      INFO: [06:49:47] Figures saved.
# LUM2_00835_VG_4114K_1.pepXML
#      INFO: [06:49:49] 1 file(s) to process.
#      INFO: [06:49:49] Loading file LUM2_00835_VG_4114K_1.pepXML...
#      INFO: [06:49:59] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 29648
#      INFO: [06:49:59] Calibrating retention model...
#      INFO: [06:50:15] RT model training results: R^2 = 0.848099 , std = 11.085604
#      INFO: [06:50:15] Retention model calibrated successfully.
#      INFO: [06:50:15] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:50:34] Machine learning is finished.
#      INFO: [06:50:38] Final results at 1.0% FDR level:
#      INFO: [06:50:38] Identified PSMs: 30913
#      INFO: [06:50:38] Identified peptides: 22614
#      INFO: [06:50:38] Identified proteins: 4106
#      INFO: [06:50:38] Identified protein groups: 3602
#      INFO: [06:50:38] Processing finished.
#      INFO: [06:50:40] Output tables saved.
#      INFO: [06:50:48] Figures saved.
# LUM2_00798_VG_6138B_1.pepXML
#      INFO: [06:50:50] 1 file(s) to process.
#      INFO: [06:50:50] Loading file LUM2_00798_VG_6138B_1.pepXML...
#      INFO: [06:51:01] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 32073
#      INFO: [06:51:01] Calibrating retention model...
#      INFO: [06:51:18] RT model training results: R^2 = 0.861332 , std = 10.937023
#      INFO: [06:51:18] Retention model calibrated successfully.
#      INFO: [06:51:19] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:51:38] Machine learning is finished.
#      INFO: [06:51:42] Final results at 1.0% FDR level:
#      INFO: [06:51:42] Identified PSMs: 33367
#      INFO: [06:51:42] Identified peptides: 23868
#      INFO: [06:51:42] Identified proteins: 4284
#      INFO: [06:51:42] Identified protein groups: 3823
#      INFO: [06:51:42] Processing finished.
#      INFO: [06:51:44] Output tables saved.
#      INFO: [06:51:53] Figures saved.
# LUM2_00817_VG_4114B_1.pepXML
#      INFO: [06:51:55] 1 file(s) to process.
#      INFO: [06:51:55] Loading file LUM2_00817_VG_4114B_1.pepXML...
#      INFO: [06:52:03] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 27689
#      INFO: [06:52:03] Calibrating retention model...
#      INFO: [06:52:18] RT model training results: R^2 = 0.842459 , std = 11.263609
#      INFO: [06:52:18] Retention model calibrated successfully.
#      INFO: [06:52:18] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:52:38] Machine learning is finished.
#      INFO: [06:52:42] Final results at 1.0% FDR level:
#      INFO: [06:52:42] Identified PSMs: 28944
#      INFO: [06:52:42] Identified peptides: 21988
#      INFO: [06:52:42] Identified proteins: 4058
#      INFO: [06:52:42] Identified protein groups: 3550
#      INFO: [06:52:42] Processing finished.
#      INFO: [06:52:44] Output tables saved.
#      INFO: [06:52:51] Figures saved.
# LUM2_00722_VG_3821B_2.pepXML
#      INFO: [06:52:53] 1 file(s) to process.
#      INFO: [06:52:53] Loading file LUM2_00722_VG_3821B_2.pepXML...
#      INFO: [06:53:05] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 37030
#      INFO: [06:53:05] Calibrating retention model...
#      INFO: [06:53:25] RT model training results: R^2 = 0.859568 , std = 10.338612
#      INFO: [06:53:25] Retention model calibrated successfully.
#      INFO: [06:53:26] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:53:49] Machine learning is finished.
#      INFO: [06:53:54] Final results at 1.0% FDR level:
#      INFO: [06:53:54] Identified PSMs: 38325
#      INFO: [06:53:54] Identified peptides: 27908
#      INFO: [06:53:54] Identified proteins: 4868
#      INFO: [06:53:54] Identified protein groups: 4216
#      INFO: [06:53:54] Processing finished.
#      INFO: [06:53:57] Output tables saved.
#      INFO: [06:54:05] Figures saved.
# LUM2_00819_VG_4114B_3.pepXML
#      INFO: [06:54:07] 1 file(s) to process.
#      INFO: [06:54:07] Loading file LUM2_00819_VG_4114B_3.pepXML...
#      INFO: [06:54:15] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 27115
#      INFO: [06:54:15] Calibrating retention model...
#      INFO: [06:54:30] RT model training results: R^2 = 0.847207 , std = 11.157222
#      INFO: [06:54:30] Retention model calibrated successfully.
#      INFO: [06:54:30] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:54:48] Machine learning is finished.
#      INFO: [06:54:51] Final results at 1.0% FDR level:
#      INFO: [06:54:51] Identified PSMs: 28519
#      INFO: [06:54:51] Identified peptides: 21585
#      INFO: [06:54:51] Identified proteins: 4015
#      INFO: [06:54:51] Identified protein groups: 3520
#      INFO: [06:54:51] Processing finished.
#      INFO: [06:54:53] Output tables saved.
#      INFO: [06:55:01] Figures saved.
# LUM2_00800_VG_6138B_3.pepXML
#      INFO: [06:55:03] 1 file(s) to process.
#      INFO: [06:55:03] Loading file LUM2_00800_VG_6138B_3.pepXML...
#      INFO: [06:55:13] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 31140
#      INFO: [06:55:13] Calibrating retention model...
#      INFO: [06:55:30] RT model training results: R^2 = 0.857613 , std = 10.901050
#      INFO: [06:55:30] Retention model calibrated successfully.
#      INFO: [06:55:30] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:55:51] Machine learning is finished.
#      INFO: [06:55:55] Final results at 1.0% FDR level:
#      INFO: [06:55:55] Identified PSMs: 32624
#      INFO: [06:55:55] Identified peptides: 23086
#      INFO: [06:55:55] Identified proteins: 4198
#      INFO: [06:55:55] Identified protein groups: 3750
#      INFO: [06:55:55] Processing finished.
#      INFO: [06:55:58] Output tables saved.
#      INFO: [06:56:06] Figures saved.
# LUM2_00858_VG_4114A_6.pepXML
#      INFO: [06:56:08] 1 file(s) to process.
#      INFO: [06:56:08] Loading file LUM2_00858_VG_4114A_6.pepXML...
#      INFO: [06:56:17] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 30485
#      INFO: [06:56:17] Calibrating retention model...
#      INFO: [06:56:34] RT model training results: R^2 = 0.850422 , std = 11.224261
#      INFO: [06:56:34] Retention model calibrated successfully.
#      INFO: [06:56:34] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:56:54] Machine learning is finished.
#      INFO: [06:56:58] Final results at 1.0% FDR level:
#      INFO: [06:56:58] Identified PSMs: 31804
#      INFO: [06:56:58] Identified peptides: 23646
#      INFO: [06:56:58] Identified proteins: 4144
#      INFO: [06:56:58] Identified protein groups: 3650
#      INFO: [06:56:58] Processing finished.
#      INFO: [06:57:01] Output tables saved.
#      INFO: [06:57:08] Figures saved.
# LUM2_00859_VG_4114A_7.pepXML
#      INFO: [06:57:10] 1 file(s) to process.
#      INFO: [06:57:10] Loading file LUM2_00859_VG_4114A_7.pepXML...
#      INFO: [06:57:20] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 30806
#      INFO: [06:57:20] Calibrating retention model...
#      INFO: [06:57:36] RT model training results: R^2 = 0.841864 , std = 11.515062
#      INFO: [06:57:36] Retention model calibrated successfully.
#      INFO: [06:57:37] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:57:59] Machine learning is finished.
#      INFO: [06:58:03] Final results at 1.0% FDR level:
#      INFO: [06:58:03] Identified PSMs: 31897
#      INFO: [06:58:03] Identified peptides: 23336
#      INFO: [06:58:03] Identified proteins: 4281
#      INFO: [06:58:03] Identified protein groups: 3767
#      INFO: [06:58:03] Processing finished.
#      INFO: [06:58:05] Output tables saved.
#      INFO: [06:58:13] Figures saved.
# LUM2_00808_VG_6138A_3.pepXML
#      INFO: [06:58:15] 1 file(s) to process.
#      INFO: [06:58:16] Loading file LUM2_00808_VG_6138A_3.pepXML...
#      INFO: [06:58:24] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 26088
#      INFO: [06:58:24] Calibrating retention model...
#      INFO: [06:58:39] RT model training results: R^2 = 0.856325 , std = 11.075685
#      INFO: [06:58:39] Retention model calibrated successfully.
#      INFO: [06:58:39] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [06:58:59] Machine learning is finished.
#      INFO: [06:59:03] Final results at 1.0% FDR level:
#      INFO: [06:59:03] Identified PSMs: 27553
#      INFO: [06:59:03] Identified peptides: 20459
#      INFO: [06:59:03] Identified proteins: 3928
#      INFO: [06:59:03] Identified protein groups: 3464
#      INFO: [06:59:03] Processing finished.
#      INFO: [06:59:05] Output tables saved.
#      INFO: [06:59:13] Figures saved.
# LUM2_00792_VG_6138K_3.pepXML
#      INFO: [06:59:15] 1 file(s) to process.
#      INFO: [06:59:15] Loading file LUM2_00792_VG_6138K_3.pepXML...
#      INFO: [06:59:27] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 30112
#      INFO: [06:59:27] Calibrating retention model...
#      INFO: [06:59:43] RT model training results: R^2 = 0.852122 , std = 11.051760
#      INFO: [06:59:43] Retention model calibrated successfully.
#      INFO: [06:59:44] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [07:00:06] Machine learning is finished.
#      INFO: [07:00:11] Final results at 1.0% FDR level:
#      INFO: [07:00:11] Identified PSMs: 31433
#      INFO: [07:00:11] Identified peptides: 22581
#      INFO: [07:00:11] Identified proteins: 4380
#      INFO: [07:00:11] Identified protein groups: 3866
#      INFO: [07:00:11] Processing finished.
#      INFO: [07:00:13] Output tables saved.
#      INFO: [07:00:21] Figures saved.
# LUM2_00809_VG_6138A_4.pepXML
#      INFO: [07:00:23] 1 file(s) to process.
#      INFO: [07:00:24] Loading file LUM2_00809_VG_6138A_4.pepXML...
#      INFO: [07:00:32] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 25858
#      INFO: [07:00:32] Calibrating retention model...
#      INFO: [07:00:47] RT model training results: R^2 = 0.855901 , std = 11.017740
#      INFO: [07:00:47] Retention model calibrated successfully.
#      INFO: [07:00:47] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [07:01:06] Machine learning is finished.
#      INFO: [07:01:10] Final results at 1.0% FDR level:
#      INFO: [07:01:10] Identified PSMs: 27359
#      INFO: [07:01:10] Identified peptides: 20511
#      INFO: [07:01:10] Identified proteins: 3922
#      INFO: [07:01:10] Identified protein groups: 3450
#      INFO: [07:01:10] Processing finished.
#      INFO: [07:01:12] Output tables saved.
#      INFO: [07:01:20] Figures saved.
# LUM2_00854_VG_4114A_2.pepXML
#      INFO: [07:01:21] 1 file(s) to process.
#      INFO: [07:01:22] Loading file LUM2_00854_VG_4114A_2.pepXML...
#      INFO: [07:01:31] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 30512
#      INFO: [07:01:31] Calibrating retention model...
#      INFO: [07:01:47] RT model training results: R^2 = 0.853726 , std = 10.977800
#      INFO: [07:01:47] Retention model calibrated successfully.
#      INFO: [07:01:48] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [07:02:08] Machine learning is finished.
#      INFO: [07:02:12] Final results at 1.0% FDR level:
#      INFO: [07:02:12] Identified PSMs: 31820
#      INFO: [07:02:12] Identified peptides: 23377
#      INFO: [07:02:12] Identified proteins: 4219
#      INFO: [07:02:12] Identified protein groups: 3705
#      INFO: [07:02:12] Processing finished.
#      INFO: [07:02:14] Output tables saved.
#      INFO: [07:02:22] Figures saved.
# LUM2_00709_VG_3821K_1.pepXML
#      INFO: [07:02:24] 1 file(s) to process.
#      INFO: [07:02:24] Loading file LUM2_00709_VG_3821K_1.pepXML...
#      INFO: [07:02:36] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 34031
#      INFO: [07:02:36] Calibrating retention model...
#      INFO: [07:02:54] RT model training results: R^2 = 0.876180 , std = 9.810339
#      INFO: [07:02:54] Retention model calibrated successfully.
#      INFO: [07:02:54] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [07:03:14] Machine learning is finished.
#      INFO: [07:03:18] Final results at 1.0% FDR level:
#      INFO: [07:03:18] Identified PSMs: 35259
#      INFO: [07:03:18] Identified peptides: 24543
#      INFO: [07:03:18] Identified proteins: 4582
#      INFO: [07:03:18] Identified protein groups: 3843
#      INFO: [07:03:18] Processing finished.
#      INFO: [07:03:21] Output tables saved.
#      INFO: [07:03:29] Figures saved.
# LUM2_00723_VG_3821B_3.pepXML
#      INFO: [07:03:31] 1 file(s) to process.
#      INFO: [07:03:31] Loading file LUM2_00723_VG_3821B_3.pepXML...
#      INFO: [07:03:43] Default target-decoy filtering, 1% PSM FDR: Number of target PSMs = 36863
#      INFO: [07:03:43] Calibrating retention model...
#      INFO: [07:04:03] RT model training results: R^2 = 0.857096 , std = 10.378031
#      INFO: [07:04:03] Retention model calibrated successfully.
#      INFO: [07:04:03] Starting machine learning...
# TBB Warning: The number of workers is currently limited to 31. The request for 111 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
#
#      INFO: [07:04:24] Machine learning is finished.
#      INFO: [07:04:29] Final results at 1.0% FDR level:
#      INFO: [07:04:29] Identified PSMs: 38215
#      INFO: [07:04:29] Identified peptides: 27693
#      INFO: [07:04:29] Identified proteins: 4837
#      INFO: [07:04:29] Identified protein groups: 4198
#      INFO: [07:04:29] Processing finished.
#      INFO: [07:04:32] Output tables saved.
#      INFO: [07:04:40] Figures saved.
# CPU times: user 38.5 s, sys: 8.49 s, total: 46.9 s
# Wall time: 48min 38s

# %% [markdown]
# # Количественный анализ + анализ дифференциальной экспресии

# %% [markdown]
# ## Считаем число белков в фасте

# %%
i = 0
for p in fasta.read(fastafile):
    i+=1
print("Число настоящих белков в базе данных:",  i//2)
# Out:
# Число настоящих белков в базе данных: 20423

# %% [markdown]
# ## Создаем sample-file

# %%
sample_df = pd.DataFrame(columns = ['File Name', 'SampleID'])
filedir = 'mzML'
for file in listdir(filedir):
    if file.endswith('protein_groups.tsv'):
        name = file.split('_protein_groups')[0]
        sample = file.split('VG_')[1].split('_')[0]
        tmp_dict = {'File Name': [file],
                    'SampleID':[sample]}
        sample_df = pd.concat([sample_df, pd.DataFrame.from_dict(tmp_dict)])
sample_df.to_csv('sample_file.csv')

# %%
sample_df
# Out:
#                                   File Name SampleID
# 0  LUM2_00791_VG_6138K_2_protein_groups.tsv    6138K
# 0  LUM2_00820_VG_4114B_4_protein_groups.tsv    4114B
# 0  LUM2_00806_VG_6138A_1_protein_groups.tsv    6138A
# 0  LUM2_00854_VG_4114A_2_protein_groups.tsv    4114A
# 0  LUM2_00857_VG_4114A_5_protein_groups.tsv    4114A
# 0  LUM2_00809_VG_6138A_4_protein_groups.tsv    6138A
# 0  LUM2_00836_VG_4114K_2_protein_groups.tsv    4114K
# 0  LUM2_00801_VG_6138B_4_protein_groups.tsv    6138B
# 0  LUM2_00793_VG_6138K_4_protein_groups.tsv    6138K
# 0  LUM2_00853_VG_4114A_1_protein_groups.tsv    4114A
# 0  LUM2_00835_VG_4114K_1_protein_groups.tsv    4114K
# 0  LUM2_00859_VG_4114A_7_protein_groups.tsv    4114A
# 0  LUM2_00808_VG_6138A_3_protein_groups.tsv    6138A
# 0  LUM2_00711_VG_3821K_3_protein_groups.tsv    3821K
# 0  LUM2_00823_VG_4114B_7_protein_groups.tsv    4114B
# 0  LUM2_00821_VG_4114B_5_protein_groups.tsv    4114B
# 0  LUM2_00798_VG_6138B_1_protein_groups.tsv    6138B
# 0  LUM2_00855_VG_4114A_3_protein_groups.tsv    4114A
# 0  LUM2_00740_VG_3821A_1_protein_groups.tsv    3821A
# 0  LUM2_00837_VG_4114K_3_protein_groups.tsv    4114K
# 0  LUM2_00799_VG_6138B_2_protein_groups.tsv    6138B
# 0  LUM2_00818_VG_4114B_2_protein_groups.tsv    4114B
# 0  LUM2_00807_VG_6138A_2_protein_groups.tsv    6138A
# 0  LUM2_00841_VG_4114K_7_protein_groups.tsv    4114K
# 0  LUM2_00743_VG_3821A_4_protein_groups.tsv    3821A
# 0  LUM2_00822_VG_4114B_6_protein_groups.tsv    4114B
# 0  LUM2_00712_VG_3821K_4_protein_groups.tsv    3821K
# 0  LUM2_00790_VG_6138K_1_protein_groups.tsv    6138K
# 0  LUM2_00709_VG_3821K_1_protein_groups.tsv    3821K
# 0  LUM2_00742_VG_3821A_3_protein_groups.tsv    3821A
# 0  LUM2_00792_VG_6138K_3_protein_groups.tsv    6138K
# 0  LUM2_00721_VG_3821B_1_protein_groups.tsv    3821B
# 0  LUM2_00840_VG_4114K_6_protein_groups.tsv    4114K
# 0  LUM2_00724_VG_3821B_4_protein_groups.tsv    3821B
# 0  LUM2_00856_VG_4114A_4_protein_groups.tsv    4114A
# 0  LUM2_00858_VG_4114A_6_protein_groups.tsv    4114A
# 0  LUM2_00838_VG_4114K_4_protein_groups.tsv    4114K
# 0  LUM2_00817_VG_4114B_1_protein_groups.tsv    4114B
# 0  LUM2_00819_VG_4114B_3_protein_groups.tsv    4114B
# 0  LUM2_00839_VG_4114K_5_protein_groups.tsv    4114K
# 0  LUM2_00710_VG_3821K_2_protein_groups.tsv    3821K
# 0  LUM2_00800_VG_6138B_3_protein_groups.tsv    6138B
# 0  LUM2_00723_VG_3821B_3_protein_groups.tsv    3821B
# 0  LUM2_00722_VG_3821B_2_protein_groups.tsv    3821B
# 0  LUM2_00741_VG_3821A_2_protein_groups.tsv    3821A

# %%
filedir = 'mzML'
sample_file = 'sample_file.csv'
outdir = 'qreps'

labels = '3821A,3821K 3821B,3821K'

# !qreps --sample-file $sample_file --labels $labels\
    --input-dir $filedir --output-dir $outdir\
    --imputation kNN --thresholds semi-dynamic --alpha 0.01 --regulation UP\
    --fasta-size 20423 --species 9606 --report True

# %% [markdown]
# ## Анализ дифференциальной экспрессии

# %%
files = glob("mzML/*_protein_groups.tsv")
data = []

for file in files:
    df = pd.read_csv(file, sep='\t')
    sample = os.path.basename(file).replace('_protein_groups.tsv', '')
    
    culture = sample.split('_VG_')[1][:4]
    condition = sample.split('_VG_')[1][4]
    
    df['culture'] = culture
    df['condition'] = condition
    df['sample'] = sample
    
    df = df[['dbname', 'NSAF', 'q', 'culture', 'condition', 'sample']]
    data.append(df)

df_all = pd.concat(data, ignore_index=True)

# %%
# Фильтрация
df_clean = df_all.dropna(subset=['NSAF'])
protein_counts = df_clean['dbname'].value_counts()
df_clean = df_clean[df_clean['dbname'].isin(protein_counts[protein_counts >= 3].index)]

results = []

# %%
# ANOVA
for protein, subdf in df_clean.groupby('dbname'):
    try:
        conds = subdf['condition'].unique()
        if not set(['A', 'B', 'K']).issubset(set(conds)):
            continue
        
        counts = subdf['condition'].value_counts()
        if any(counts < 2):
            continue  # пропускаем белки с малым числом наблюдений
        
        model = ols('NSAF ~ C(condition)', data=subdf).fit()
        
        if model.df_resid <= 0:
            continue

        anova_table = sm.stats.anova_lm(model, typ=2)
        pval = anova_table["PR(>F)"].iloc[0]
        
        results.append({'dbname': protein, 'anova_pval': pval})
    except Exception:
        continue

# %%
anova_df = pd.DataFrame(results)
anova_df['padj'] = sm.stats.multipletests(anova_df['anova_pval'], method='fdr_bh')[1]

# %%
sig_proteins = anova_df[anova_df['padj'] < 0.05]['dbname']

# %%
# Тест Тьюки

tukey_results = []
for protein in sig_proteins:
    subdf = df_clean[df_clean['dbname'] == protein]
    tukey = pairwise_tukeyhsd(subdf['NSAF'], subdf['condition'], alpha=0.05)
    tukey_df = pd.DataFrame(data=tukey.summary().data[1:], columns=tukey.summary().data[0])
    tukey_df['dbname'] = protein
    tukey_results.append(tukey_df)

tukey_all = pd.concat(tukey_results, ignore_index=True)

# %%
# Боксплоты для нескольких белков

for protein in sig_proteins[:5]:
    sub = df_clean[df_clean['dbname'] == protein]
    plt.figure()
    sub.boxplot(column='NSAF', by='condition', grid=False)
    plt.title(f'Protein: {protein}')
    plt.suptitle('')
    plt.xlabel('Condition')
    plt.ylabel('NSAF')
    plt.tight_layout()
    plt.show()

# %%
anova_df.to_csv('anova_results.csv', index=False)
tukey_all.to_csv('tukey_results.csv', index=False)
sig_proteins.to_csv('sig_anova_results.csv', index=False)

# %% [markdown]
# Выводы: был получен список дифференциально представленных белков в сравнении между двумя группами по приему интерферона и контрольной группой (sig_anova_results.csv). С применением теста Тьюки, для каждого белка была выявлена группа, для которой содержание белка повышено или понижено (tukey_results.csv).
